# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv("covid19_Confirmed_dataset.csv")
dataset.head(5)
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# 0     1463     1531     1703     1828     1939     2171
# 1      712      726      736      750      766      773
# 2     3256     3382     3517     3649     3848     4006
# 3      738      738      743      743      743      745
# 4       25       26       27       27       27       27
#
# [5 rows x 104 columns]

# %%
dataset.shape
# Out:
# (266, 104)

# %%
df = dataset.drop(["Lat","Long"], axis = 1, inplace = True)

# %%
dataset
# Out:
#     Province/State         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              NaN            Afghanistan        0        0        0        0
# 1              NaN                Albania        0        0        0        0
# 2              NaN                Algeria        0        0        0        0
# 3              NaN                Andorra        0        0        0        0
# 4              NaN                 Angola        0        0        0        0
# ..             ...                    ...      ...      ...      ...      ...
# 261            NaN         Western Sahara        0        0        0        0
# 262            NaN  Sao Tome and Principe        0        0        0        0
# 263            NaN                  Yemen        0        0        0        0
# 264            NaN                Comoros        0        0        0        0
# 265            NaN             Tajikistan        0        0        0        0
#
#      1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  \
# 0          0        0        0        0  ...     1092     1176     1279
# 1          0        0        0        0  ...      609      634      663
# 2          0        0        0        0  ...     2811     2910     3007
# 3          0        0        0        0  ...      717      723      723
# 4          0        0        0        0  ...       24       25       25
# ..       ...      ...      ...      ...  ...      ...      ...      ...
# 261        0        0        0        0  ...        6        6        6
# 262        0        0        0        0  ...        4        4        4
# 263        0        0        0        0  ...        1        1        1
# 264        0        0        0        0  ...        0        0        0
# 265        0        0        0        0  ...        0        0        0
#
#      4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# 0       1351     1463     1531     1703     1828     1939     2171
# 1        678      712      726      736      750      766      773
# 2       3127     3256     3382     3517     3649     3848     4006
# 3        731      738      738      743      743      743      745
# 4         25       25       26       27       27       27       27
# ..       ...      ...      ...      ...      ...      ...      ...
# 261        6        6        6        6        6        6        6
# 262        4        4        4        4        8        8       14
# 263        1        1        1        1        1        6        6
# 264        0        0        0        0        0        0        1
# 265        0        0        0        0        0        0       15
#
# [266 rows x 102 columns]

# %%
corona_dataset_aggregated = dataset.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head(6)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  4/21/20  \
# Country/Region                                           ...
# Afghanistan                0        0        0        0  ...     1092
# Albania                    0        0        0        0  ...      609
# Algeria                    0        0        0        0  ...     2811
# Andorra                    0        0        0        0  ...      717
# Angola                     0        0        0        0  ...       24
# Antigua and Barbuda        0        0        0        0  ...       23
#
#                      4/22/20  4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  \
# Country/Region
# Afghanistan             1176     1279     1351     1463     1531     1703
# Albania                  634      663      678      712      726      736
# Algeria                 2910     3007     3127     3256     3382     3517
# Andorra                  723      723      731      738      738      743
# Angola                    25       25       25       25       26       27
# Antigua and Barbuda       24       24       24       24       24       24
#
#                      4/28/20  4/29/20  4/30/20
# Country/Region
# Afghanistan             1828     1939     2171
# Albania                  750      766      773
# Algeria                 3649     3848     4006
# Andorra                  743      743      745
# Angola                    27       27       27
# Antigua and Barbuda       24       24       24
#
# [6 rows x 100 columns]

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %%
corona_dataset_aggregated.loc["China"].plot();
corona_dataset_aggregated.loc["India"].plot();
corona_dataset_aggregated.loc["Spain"].plot();
corona_dataset_aggregated.loc["Italy"].plot();
plt.legend();

# %%
corona_dataset_aggregated.loc["China"][:5].plot();

# %%
#Calculating first derivative
corona_dataset_aggregated.loc["China"].diff().plot();

# %%
corona_dataset_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc["Spain"].diff().max()
# Out:
# 9630.0

# %%
corona_dataset_aggregated.loc["India"].diff().max()
# Out:
# 1893.0

# %%
corona_dataset_aggregated.loc["Italy"].diff().max()
# Out:
# 6557.0

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []

for c in countries:
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
corona_dataset_aggregated["Max_infection_rates"] = max_infection_rates

# %%
corona_dataset_aggregated
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
#                     1/28/20  1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  \
# Country/Region                                          ...
# Afghanistan               0        0        0        0  ...     1176     1279
# Albania                   0        0        0        0  ...      634      663
# Algeria                   0        0        0        0  ...     2910     3007
# Andorra                   0        0        0        0  ...      723      723
# Angola                    0        0        0        0  ...       25       25
# ...                     ...      ...      ...      ...  ...      ...      ...
# West Bank and Gaza        0        0        0        0  ...      474      480
# Western Sahara            0        0        0        0  ...        6        6
# Yemen                     0        0        0        0  ...        1        1
# Zambia                    0        0        0        0  ...       74       76
# Zimbabwe                  0        0        0        0  ...       28       28
#
#                     4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  \
# Country/Region
# Afghanistan            1351     1463     1531     1703     1828     1939
# Albania                 678      712      726      736      750      766
# Algeria                3127     3256     3382     3517     3649     3848
# Andorra                 731      738      738      743      743      743
# Angola                   25       25       26       27       27       27
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza      484      342      342      342      343      344
# Western Sahara            6        6        6        6        6        6
# Yemen                     1        1        1        1        1        6
# Zambia                   84       84       88       88       95       97
# Zimbabwe                 29       31       31       32       32       32
#
#                     4/30/20  Max_infection_rates
# Country/Region
# Afghanistan            2171                232.0
# Albania                 773                 34.0
# Algeria                4006                199.0
# Andorra                 745                 43.0
# Angola                   27                  5.0
# ...                     ...                  ...
# West Bank and Gaza      344                 66.0
# Western Sahara            6                  4.0
# Yemen                     6                  5.0
# Zambia                  106                  9.0
# Zimbabwe                 40                  8.0
#
# [187 rows x 101 columns]

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated["Max_infection_rates"])

# %%
corona_data.plot();

# %%
corona_data
# Out:
#                     Max_infection_rates
# Country/Region
# Afghanistan                       232.0
# Albania                            34.0
# Algeria                           199.0
# Andorra                            43.0
# Angola                              5.0
# ...                                 ...
# West Bank and Gaza                 66.0
# Western Sahara                      4.0
# Yemen                               5.0
# Zambia                              9.0
# Zimbabwe                            8.0
#
# [187 rows x 1 columns]

# %%
#Importing 2nd database
happiness_report = pd.read_csv("worldwide_happiness_report.csv")

# %%
happiness_report
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
happiness_report.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
# 5         0.03140                   1.29025  1.31826
# 6         0.02799                   1.32944  1.28017
# 7         0.03157                   1.33171  1.28907
# 8         0.03371                   1.25018  1.31967
# 9         0.04083                   1.33358  1.30923
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
# 5                   0.88911  0.64169                        0.41372
# 6                   0.89284  0.61576                        0.31814
# 7                   0.91087  0.65980                        0.43844
# 8                   0.90837  0.63938                        0.42922
# 9                   0.93156  0.65124                        0.35637
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176
# 5     0.23351            2.61955
# 6     0.47610            2.46570
# 7     0.36262            2.37119
# 8     0.47501            2.26425
# 9     0.43562            2.26646

# %%
useless_columns = ["Happiness Rank","Standard Error","Generosity","Region","Dystopia Residual"]

# %%
happiness_report.drop(useless_columns, axis = 1, inplace = True)

# %%
happiness_report
# Out:
#          Country  Happiness Score  Economy (GDP per Capita)   Family  \
# 0    Switzerland            7.587                   1.39651  1.34951
# 1        Iceland            7.561                   1.30232  1.40223
# 2        Denmark            7.527                   1.32548  1.36058
# 3         Norway            7.522                   1.45900  1.33095
# 4         Canada            7.427                   1.32629  1.32261
# ..           ...              ...                       ...      ...
# 153       Rwanda            3.465                   0.22208  0.77370
# 154        Benin            3.340                   0.28665  0.35386
# 155        Syria            3.006                   0.66320  0.47489
# 156      Burundi            2.905                   0.01530  0.41587
# 157         Togo            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
# [158 rows x 7 columns]

# %%
corona_data.shape
# Out:
# (187, 1)

# %%
happiness_report.shape
# Out:
# (158, 6)

# %%
data = corona_data.join(happiness_report, how = "inner")
data
# Out:
#              Max_infection_rates  Happiness Score  Economy (GDP per Capita)  \
# Afghanistan                232.0            3.575                   0.31982
# Albania                     34.0            4.959                   0.87867
# Algeria                    199.0            5.605                   0.93929
# Angola                       5.0            4.033                   0.75778
# Argentina                  291.0            6.574                   1.05351
# ...                          ...              ...                       ...
# Venezuela                   29.0            6.810                   1.04424
# Vietnam                     19.0            5.360                   0.63216
# Yemen                        5.0            4.077                   0.54649
# Zambia                       9.0            5.129                   0.47038
# Zimbabwe                     8.0            4.610                   0.27100
#
#               Family  Health (Life Expectancy)  Freedom  \
# Afghanistan  0.30285                   0.30335  0.23414
# Albania      0.80434                   0.81325  0.35733
# Algeria      1.07772                   0.61766  0.28579
# Angola       0.86040                   0.16683  0.10384
# Argentina    1.24823                   0.78723  0.44974
# ...              ...                       ...      ...
# Venezuela    1.25596                   0.72052  0.42908
# Vietnam      0.91226                   0.74676  0.59444
# Yemen        0.68093                   0.40064  0.35571
# Zambia       0.91612                   0.29924  0.48827
# Zimbabwe     1.03276                   0.33475  0.25861
#
#              Trust (Government Corruption)
# Afghanistan                        0.09719
# Albania                            0.06413
# Algeria                            0.17383
# Angola                             0.07122
# Argentina                          0.08484
# ...                                    ...
# Venezuela                          0.11069
# Vietnam                            0.10441
# Yemen                              0.07854
# Zambia                             0.12468
# Zimbabwe                           0.08079
#
# [144 rows x 7 columns]

# %%
data.corr()
# Out:
#                                Max_infection_rates  Happiness Score  \
# Max_infection_rates                       1.000000         0.227333
# Happiness Score                           0.227333         1.000000
# Economy (GDP per Capita)                  0.235445         0.782725
# Family                                    0.176345         0.740520
# Health (Life Expectancy)                  0.286783         0.738470
# Freedom                                   0.110988         0.580437
# Trust (Government Corruption)             0.047062         0.436289
#
#                                Economy (GDP per Capita)    Family  \
# Max_infection_rates                            0.235445  0.176345
# Happiness Score                                0.782725  0.740520
# Economy (GDP per Capita)                       1.000000  0.651997
# Family                                         0.651997  1.000000
# Health (Life Expectancy)                       0.822992  0.560885
# Freedom                                        0.373916  0.448943
# Trust (Government Corruption)                  0.357078  0.220285
#
#                                Health (Life Expectancy)   Freedom  \
# Max_infection_rates                            0.286783  0.110988
# Happiness Score                                0.738470  0.580437
# Economy (GDP per Capita)                       0.822992  0.373916
# Family                                         0.560885  0.448943
# Health (Life Expectancy)                       1.000000  0.368250
# Freedom                                        0.368250  1.000000
# Trust (Government Corruption)                  0.280663  0.491964
#
#                                Trust (Government Corruption)
# Max_infection_rates                                 0.047062
# Happiness Score                                     0.436289
# Economy (GDP per Capita)                            0.357078
# Family                                              0.220285
# Health (Life Expectancy)                            0.280663
# Freedom                                             0.491964
# Trust (Government Corruption)                       1.000000

# %%
y = data["Max_infection_rates"]
x = data["Economy (GDP per Capita)"]
sns.scatterplot(x,np.log(y)); #logscaling
# Out:
# C:\Users\XINSlim3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.regplot(x,np.log(y));
# Out:
# C:\Users\XINSlim3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
y = data["Max_infection_rates"]
x = data["Health (Life Expectancy)"]
sns.scatterplot(x,np.log(y));

# %%
sns.regplot(x,np.log(y));
# Out:
# C:\Users\XINSlim3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
y = data["Max_infection_rates"]
x = data["Happiness Score"]
sns.scatterplot(x,np.log(y));

# %%
sns.regplot(x,np.log(y));
# Out:
# C:\Users\XINSlim3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
y = data["Max_infection_rates"]
x = data["Trust (Government Corruption)"]
sns.scatterplot(x,np.log(y));

# %%
sns.regplot(x,np.log(y));
# Out:
# C:\Users\XINSlim3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
